# %% [markdown]
# # STACKWISE — Dataset Registry Audit
#
# This notebook audits only the machine-readable public dataset registry. It does not download external data.

# %%
from stackwise.audit import write_audit
paths = write_audit(output_dir='../results/notebook_audit')
paths

# %%
import pandas as pd
pd.read_csv(paths['audit']).head(20)

# %%
pd.read_csv(paths['matrix'], index_col=0)

# %% [markdown]
# # STACKWISE — Self-Contained Smoke Pipeline
#
# The data in this notebook are synthetic test fixtures and are not research evidence.

# %%
from stackwise.reproduce import reproduce_smoke
outputs = reproduce_smoke('../results/notebook_smoke')
outputs

# %%
from pathlib import Path
print(Path(outputs['fleet_solution']).read_text())
